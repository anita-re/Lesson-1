# %%
# !pip install matplotlib

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

xpts= np.array([0,4])
ypts=np.array([0,100])

plt.plot(xpts,ypts)
plt.show()

# %%
import numpy as np

xpts= np.array([0, 60])
ypts=np.array([0,440])

import matplotlib.pyplot as plt

plt.plot(xpts,ypts)
plt.show()

# %%
# !pip install scikit-learn

# %%
import sklearn as sl

# %%
# !pip install jupyter h5
# Out:
# ...
#   Using cached h5-0.8.4-py3-none-any.whl (7.7 kB)
# ...

# %%
# !pip install jupyterlab_h5web
# Out:
# ...
#      ------------------------------------ 742.8/742.8 kB 709.9 kB/s eta 0:00:00
# ...
#      ------------------------------------ 202.1/202.1 kB 223.3 kB/s eta 0:00:00
# ...
